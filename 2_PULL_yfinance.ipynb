# %%
import os
import pandas as pd
import pandas_datareader # had to install with pip
import datetime

# note, this is the 3rd version of pull.  
#    the first version used quandle which was closed down and disconintued
#    the second version used iextrading which is limitted unless you pay

# As a free source, it is great for playing with data.  For production or use in algotraiding, it is highly
#   Recomended by many tutorials to use a paid service that is more reliable.
#   As of publishing this, yfinance is still the only free pull

# As of first writing this script in 2016 to running the script in 2023, Errors have changed
#   Limits on number of pulls of day granularity have not been addressed.

# as of 1/11/2023 -- Does not run in python 3.10, 3.9.7
#    Is working in Python 3.7

import yfinance as yf
        
class stockPull_yfinance():
    # from viewing a single pull, the following format is what comes out
    #      Date	Open	High	Low	Close	Volume	Dividends	Stock Splits
    #      note default loads Date as index.... 
    mapCols = ['date', 'open', 'high', 'low', 'close', 'volume', 'dividends', 'stocksplits']
    
    trackName = 'NONE'
    trackDB = pd.DataFrame()
    def __init__(self, stockTP):
        self.stockPath = stockTP
        self.errors = dict()

    def pullAllStocks(self):
        self.errors = dict()
        try:
            # ------  pulls ALL the symbols from nasdaq ------  as index. 
            #     There is additional information on the stock which should be looked at for possible
            #          possible 'features' that can be used in prediction models
            dfStocks = pandas_datareader.nasdaq_trader.get_nasdaq_symbols(retry_count=3, timeout=30, pause=None)
            symbols = dfStocks.index.values
            
            print("pull values from nasdaq.  Note only the stock symbol, index, is used for pulling data.")
            print()
            print(dfStocks.head())
            print()
            print("====================== Pulling individual stocks ============================")
            print()
            
            # ----------------- for testing, this can be limitted with symbols[4:7] etc. so all 9000+ downloads aren't triggered
            for symb in symbols: # --- cleaning the symbols to match correctly.  Note error printout, not all are pulling
                s = symb.replace('^','-').split(".")[0]
                s = s.replace('~','-')
                s = s.replace('$','-') # quandl
                s.strip()
                self.pullStockSymb(s)
        except Exception as e:
            print("error pulling stock list, NO stocks updated", e)
        return self.errors
    
    def pullStockSymb(self, symb):
        
        try:
            fileFullPath = self.stockPath + symb + ".csv"
            # ---------  if exists, open, pull new data, add to dataframe and save
            if os.path.exists(fileFullPath):
                dfH = pd.read_csv(fileFullPath, index_col=0)
                d = datetime.datetime.strptime(dfH.index[-1], '%Y-%m-%d').date()+  datetime.timedelta(days=-10)
                start = d.strftime('%Y-%m-%d')
                # pull only current data on   progress=False to yf.download() suppresses progress bar
                dfH2 = yf.download(symb, start=d, progress=False)#, end="2017-04-30")
                if len(dfH2.index) >= 1: # only make changes if there is new data
                    dfH2 = dfH2.round(2)
                    dfH2.index = dfH2.index.strftime('%Y-%m-%d')
                    dfH = pd.concat([dfH, dfH2])#.index.drop_duplicates()#.reset_index(drop=True)
                    dfH = dfH.loc[~dfH.index.duplicated(keep='last')] 
                    dfH.to_csv(fileFullPath, index=True)
            else:
                # ----- new stock symbol, pull all
                stockPull = yf.Ticker(symb) # suppress progress bar doesn't work on full pull
                dfH = yf.download(symb)
                dfH = dfH.round(2)
                dfH.to_csv(fileFullPath, index=True)
            # print(symb, end=",  ") 
            
        except Exception as e:
            # print(symb, end="_err,  ")
            self.errors[symb]=e

stockSave = 'D:/data/stocks/stocksIndividual_yfinanceRaw/'
print("File and path saving stock into:", stockSave)
print("     note automatically created.")
print()

# create stock pull object
spc = stockPull_yfinance(stockSave)  

#spc.pullStockSymb('AA')  # --------------------------- pulling a single stock
errorsPull = spc.pullAllStocks() # returns spc.errors
print()
print('error cnt', len(spc.errors))
print()
for symb, err in errorsPull.items():
    print(symb, " ", err)
print()    
print('======done==============')
# Out:
# File and path saving stock into: D:/data/stocks/stocksIndividual_yfinanceRaw/
#      note automatically created.
#
# pull values from nasdaq.  Note only the stock symbol, index, is used for pulling data.
#
#         Nasdaq Traded                                      Security Name  \
# Symbol
# A                True            Agilent Technologies, Inc. Common Stock
# AA               True                    Alcoa Corporation Common Stock
# AAA              True  Investment Managers Series Trust II AXS First ...
# AAAU             True             Goldman Sachs Physical Gold ETF Shares
# AAC              True  Ares Acquisition Corporation Class A Ordinary ...
#
#        Listing Exchange Market Category    ETF  Round Lot Size  Test Issue  \
# Symbol
# A                     N                  False           100.0       False
# AA                    N                  False           100.0       False
# AAA                   P                   True           100.0       False
# AAAU                  Z                   True           100.0       False
# AAC                   N                  False           100.0       False
#
#        Financial Status CQS Symbol NASDAQ Symbol  NextShares
# Symbol
# A                   NaN          A             A       False
# AA                  NaN         AA            AA       False
# AAA                 NaN        AAA           AAA       False
# AAAU                NaN       AAAU          AAAU       False
# AAC                 NaN        AAC           AAC       False
#
# ====================== Pulling individual stocks ============================
#
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAM-A: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AAM-B: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACABW: 1d data not available for startTime=-2208994789 and endTime=1673455330. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACACW: 1d data not available for startTime=-2208994789 and endTime=1673455333. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACAXR: 1d data not available for startTime=-2208994789 and endTime=1673455338. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACAXW: 1d data not available for startTime=-2208994789 and endTime=1673455339. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACDCW: 1d data not available for startTime=-2208994789 and endTime=1673455343. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ACONW: 1d data not available for startTime=-2208994789 and endTime=1673455360. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ADSEW: 1d data not available for startTime=-2208994789 and endTime=1673455402. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ADTHW: 1d data not available for startTime=-2208994789 and endTime=1673455405. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFARW: 1d data not available for startTime=-2208994789 and endTime=1673455436. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AFRIW: 1d data not available for startTime=-2208994789 and endTime=1673455445. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AHRNW: 1d data not available for startTime=-2208994789 and endTime=1673455487. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIBBR: 1d data not available for startTime=-2208994789 and endTime=1673455490. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIMAW: 1d data not available for startTime=-2208994789 and endTime=1673455498. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AIMDW: 1d data not available for startTime=-2208994789 and endTime=1673455501. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALORW: 1d data not available for startTime=-2208994789 and endTime=1673455551. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALSAR: 1d data not available for startTime=-2208994789 and endTime=1673455561. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALSAW: 1d data not available for startTime=-2208994789 and endTime=1673455562. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALTIW: 1d data not available for startTime=-2208994789 and endTime=1673455565. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ALVOW: 1d data not available for startTime=-2208994789 and endTime=1673455572. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AMLI: 1d data not available for startTime=-2208994789 and endTime=1673455597. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ANGHW: 1d data not available for startTime=-2208994789 and endTime=1673455634. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AOGOW: 1d data not available for startTime=-2208994789 and endTime=1673455647. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - APCXW: 1d data not available for startTime=-2208994789 and endTime=1673455662. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - APGNW: No data found for this date range, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - APXIW: 1d data not available for startTime=-2208994789 and endTime=1673455695. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AQUNR: 1d data not available for startTime=-2208994789 and endTime=1673455702. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AREBW: 1d data not available for startTime=-2208994789 and endTime=1673455721. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ASCAR: 1d data not available for startTime=-2208994789 and endTime=1673455763. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ASCAW: 1d data not available for startTime=-2208994789 and endTime=1673455764. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ASCBR: 1d data not available for startTime=-2208994789 and endTime=1673455765. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ASCBW: 1d data not available for startTime=-2208994789 and endTime=1673455766. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ATAKR: 1d data not available for startTime=-2208994789 and endTime=1673455794. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ATAKW: 1d data not available for startTime=-2208994789 and endTime=1673455795. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ATH-E: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - AULT-D: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BAC-S: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BCSAW: 1d data not available for startTime=-2208994789 and endTime=1673455977. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BIAFW: 1d data not available for startTime=-2208994789 and endTime=1673456050. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BIOSW: 1d data not available for startTime=-2208994789 and endTime=1673456065. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BLEUR: 1d data not available for startTime=-2208994789 and endTime=1673456124. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BLEUW: 1d data not available for startTime=-2208994789 and endTime=1673456125. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BOCNW: 1d data not available for startTime=-2208994789 and endTime=1673456196. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BPACW: 1d data not available for startTime=-2208994789 and endTime=1673456214. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRACR: 1d data not available for startTime=-2208994789 and endTime=1673456225. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRKHW: 1d data not available for startTime=-2208994789 and endTime=1673456242. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BRSHW: 1d data not available for startTime=-2208994789 and endTime=1673456253. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BTMDW: 1d data not available for startTime=-2208994789 and endTime=1673456309. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BWAQR: 1d data not available for startTime=-2208994789 and endTime=1673456337. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BWAQW: 1d data not available for startTime=-2208994789 and endTime=1673456338. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - BYNOW: 1d data not available for startTime=-2208994789 and endTime=1673456362. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CBRGW: 1d data not available for startTime=-2208994789 and endTime=1673456426. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CCLD: 1d data not available for startTime=-2208994789 and endTime=1673456444. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CCLDO: 1d data not available for startTime=-2208994789 and endTime=1673456444. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CCLDP: 1d data not available for startTime=-2208994789 and endTime=1673456445. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CCTSW: 1d data not available for startTime=-2208994789 and endTime=1673456456. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CDIOW: 1d data not available for startTime=-2208994789 and endTime=1673456466. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CEADW: 1d data not available for startTime=-2208994789 and endTime=1673456479. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CELG: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CFFSW: 1d data not available for startTime=-2208994789 and endTime=1673456514. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CHEAW: 1d data not available for startTime=-2208994789 and endTime=1673456545. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CITEW: 1d data not available for startTime=-2208994789 and endTime=1673456602. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CLRCR: 1d data not available for startTime=-2208994789 and endTime=1673456639. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CLRCW: 1d data not available for startTime=-2208994789 and endTime=1673456640. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CMCAW: 1d data not available for startTime=-2208994789 and endTime=1673456658. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CMPOW: 1d data not available for startTime=-2208994789 and endTime=1673456669. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CMRAW: 1d data not available for startTime=-2208994789 and endTime=1673456673. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CNGLW: 1d data not available for startTime=-2208994789 and endTime=1673456692. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - COEPW: 1d data not available for startTime=-2208994789 and endTime=1673456716. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CPAQW: 1d data not available for startTime=-2208994789 and endTime=1673456756. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CPTNW: 1d data not available for startTime=-2208994789 and endTime=1673456775. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CRECW: 1d data not available for startTime=-2208994789 and endTime=1673456789. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CSLMR: 1d data not available for startTime=-2208994789 and endTime=1673456826. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CSLMW: 1d data not available for startTime=-2208994789 and endTime=1673456827. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - CSSEL: 1d data not available for startTime=-2208994789 and endTime=1673456832. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DAVEW: 1d data not available for startTime=-2208994789 and endTime=1673456946. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DCFCW: 1d data not available for startTime=-2208994789 and endTime=1673456974. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DECAW: 1d data not available for startTime=-2208994789 and endTime=1673456995. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DFLIW: 1d data not available for startTime=-2208994789 and endTime=1673457031. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DHACW: 1d data not available for startTime=-2208994789 and endTime=1673457058. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DPCSW: 1d data not available for startTime=-2208994789 and endTime=1673457146. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DRCTW: 1d data not available for startTime=-2208994789 and endTime=1673457151. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DRTSW: 1d data not available for startTime=-2208994789 and endTime=1673457162. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - DUETW: 1d data not available for startTime=-2208994789 and endTime=1673457198. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ECXWW: 1d data not available for startTime=-2208994789 and endTime=1673457278. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EDBLW: 1d data not available for startTime=-2208994789 and endTime=1673457281. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EFHTR: 1d data not available for startTime=-2208994789 and endTime=1673457313. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EFHTW: 1d data not available for startTime=-2208994789 and endTime=1673457313. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EMCGR: 1d data not available for startTime=-2208994789 and endTime=1673457378. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EMCGW: 1d data not available for startTime=-2208994789 and endTime=1673457379. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EMLDW: 1d data not available for startTime=-2208994789 and endTime=1673457395. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ENAV: No timezone found, symbol may be delisted
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - ENCPW: 1d data not available for startTime=-2208994789 and endTime=1673457411. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EUDAW: 1d data not available for startTime=-2208994789 and endTime=1673457532. Only 100 years worth of day granularity data are allowed to be fetched per request.
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# ...
# AHT-I   index -1 is out of bounds for axis 0 with size 0
# AIG-A   index -1 is out of bounds for axis 0 with size 0
# AKO   index -1 is out of bounds for axis 0 with size 0
# AL-A   index -1 is out of bounds for axis 0 with size 0
# ALL-B   index -1 is out of bounds for axis 0 with size 0
# ALL-G   index -1 is out of bounds for axis 0 with size 0
# ALL-H   index -1 is out of bounds for axis 0 with size 0
# ALL-I   index -1 is out of bounds for axis 0 with size 0
# ALTG-A   index -1 is out of bounds for axis 0 with size 0
# AMCIW   index -1 is out of bounds for axis 0 with size 0
# AMH-G   index -1 is out of bounds for axis 0 with size 0
# AMH-H   index -1 is out of bounds for axis 0 with size 0
# APCA   index -1 is out of bounds for axis 0 with size 0
# APTV-A   index -1 is out of bounds for axis 0 with size 0
# ARGO-A   index -1 is out of bounds for axis 0 with size 0
# ARR-C   index -1 is out of bounds for axis 0 with size 0
# ARTLW   index -1 is out of bounds for axis 0 with size 0
# ASB-E   index -1 is out of bounds for axis 0 with size 0
# ASB-F   index -1 is out of bounds for axis 0 with size 0
# ATCO-D   index -1 is out of bounds for axis 0 with size 0
# ATCO-H   index -1 is out of bounds for axis 0 with size 0
# ATCO-I   index -1 is out of bounds for axis 0 with size 0
# ATEST   index -1 is out of bounds for axis 0 with size 0
# ATH-A   index -1 is out of bounds for axis 0 with size 0
# ATH-B   index -1 is out of bounds for axis 0 with size 0
# ATH-C   index -1 is out of bounds for axis 0 with size 0
# ATH-D   index -1 is out of bounds for axis 0 with size 0
# AVCTW   index -1 is out of bounds for axis 0 with size 0
# AXS-E   index -1 is out of bounds for axis 0 with size 0
# BAC-B   index -1 is out of bounds for axis 0 with size 0
# BAC-E   index -1 is out of bounds for axis 0 with size 0
# BAC-K   index -1 is out of bounds for axis 0 with size 0
# BAC-L   index -1 is out of bounds for axis 0 with size 0
# BAC-M   index -1 is out of bounds for axis 0 with size 0
# BAC-N   index -1 is out of bounds for axis 0 with size 0
# BAC-O   index -1 is out of bounds for axis 0 with size 0
# BAC-P   index -1 is out of bounds for axis 0 with size 0
# BAC-Q   index -1 is out of bounds for axis 0 with size 0
# BC-A   index -1 is out of bounds for axis 0 with size 0
# BC-B   index -1 is out of bounds for axis 0 with size 0
# BC-C   index -1 is out of bounds for axis 0 with size 0
# BCDAW   index -1 is out of bounds for axis 0 with size 0
# BCV-A   index -1 is out of bounds for axis 0 with size 0
# BEP-A   index -1 is out of bounds for axis 0 with size 0
# BF   index -1 is out of bounds for axis 0 with size 0
# BFAC   index -1 is out of bounds for axis 0 with size 0
# BFS-D   index -1 is out of bounds for axis 0 with size 0
# BFS-E   index -1 is out of bounds for axis 0 with size 0
# BHR-B   index -1 is out of bounds for axis 0 with size 0
# BHR-D   index -1 is out of bounds for axis 0 with size 0
# BIP-A   index -1 is out of bounds for axis 0 with size 0
# BIP-B   index -1 is out of bounds for axis 0 with size 0
# BKES   index -1 is out of bounds for axis 0 with size 0
# BKIS   index -1 is out of bounds for axis 0 with size 0
# BKUS   index -1 is out of bounds for axis 0 with size 0
# BLNKW   index -1 is out of bounds for axis 0 with size 0
# BML-G   index -1 is out of bounds for axis 0 with size 0
# BML-H   index -1 is out of bounds for axis 0 with size 0
# BML-J   index -1 is out of bounds for axis 0 with size 0
# BML-L   index -1 is out of bounds for axis 0 with size 0
# BNGOW   index -1 is out of bounds for axis 0 with size 0
# BOH-A   index -1 is out of bounds for axis 0 with size 0
# BRD   index -1 is out of bounds for axis 0 with size 0
# BROGW   index -1 is out of bounds for axis 0 with size 0
# BSGAR   index -1 is out of bounds for axis 0 with size 0
# BSX-A   index -1 is out of bounds for axis 0 with size 0
# BW-A   index -1 is out of bounds for axis 0 with size 0
# BWMX   index -1 is out of bounds for axis 0 with size 0
# C-J   index -1 is out of bounds for axis 0 with size 0
# C-K   index -1 is out of bounds for axis 0 with size 0
# C-N   index -1 is out of bounds for axis 0 with size 0
# CADE-A   index -1 is out of bounds for axis 0 with size 0
# CBO   index -1 is out of bounds for axis 0 with size 0
# CBX   index -1 is out of bounds for axis 0 with size 0
# CDR-B   index -1 is out of bounds for axis 0 with size 0
# CDR-C   index -1 is out of bounds for axis 0 with size 0
# CEQP-   index -1 is out of bounds for axis 0 with size 0
# CFG-D   index -1 is out of bounds for axis 0 with size 0
# CFG-E   index -1 is out of bounds for axis 0 with size 0
# CFR-B   index -1 is out of bounds for axis 0 with size 0
# CHEKZ   index -1 is out of bounds for axis 0 with size 0
# CHMI-A   index -1 is out of bounds for axis 0 with size 0
# CHMI-B   index -1 is out of bounds for axis 0 with size 0
# CIM-A   index -1 is out of bounds for axis 0 with size 0
# CIM-B   index -1 is out of bounds for axis 0 with size 0
# CIM-C   index -1 is out of bounds for axis 0 with size 0
# CIM-D   index -1 is out of bounds for axis 0 with size 0
# CIO-A   index -1 is out of bounds for axis 0 with size 0
# CLDT-A   index -1 is out of bounds for axis 0 with size 0
# CLVT-A   index -1 is out of bounds for axis 0 with size 0
# CMRE-B   index -1 is out of bounds for axis 0 with size 0
# CMRE-C   index -1 is out of bounds for axis 0 with size 0
# CMRE-D   index -1 is out of bounds for axis 0 with size 0
# CMRE-E   index -1 is out of bounds for axis 0 with size 0
# CMS-B   index -1 is out of bounds for axis 0 with size 0
# CMS-C   index -1 is out of bounds for axis 0 with size 0
# CNDB   index -1 is out of bounds for axis 0 with size 0
# CNO-A   index -1 is out of bounds for axis 0 with size 0
# CODI-A   index -1 is out of bounds for axis 0 with size 0
# CODI-B   index -1 is out of bounds for axis 0 with size 0
# CODI-C   index -1 is out of bounds for axis 0 with size 0
# COF-I   index -1 is out of bounds for axis 0 with size 0
# COF-J   index -1 is out of bounds for axis 0 with size 0
# COF-K   index -1 is out of bounds for axis 0 with size 0
# COF-L   index -1 is out of bounds for axis 0 with size 0
# COF-N   index -1 is out of bounds for axis 0 with size 0
# CORR-A   index -1 is out of bounds for axis 0 with size 0
# CPAAW   index -1 is out of bounds for axis 0 with size 0
# CREXW   index -1 is out of bounds for axis 0 with size 0
# CSR-C   index -1 is out of bounds for axis 0 with size 0
# CTA-A   index -1 is out of bounds for axis 0 with size 0
# CTA-B   index -1 is out of bounds for axis 0 with size 0
# CTEST   index -1 is out of bounds for axis 0 with size 0
# CTO-A   index -1 is out of bounds for axis 0 with size 0
# CUBI-E   index -1 is out of bounds for axis 0 with size 0
# CUBI-F   index -1 is out of bounds for axis 0 with size 0
# DBRG-H   index -1 is out of bounds for axis 0 with size 0
# DBRG-I   index -1 is out of bounds for axis 0 with size 0
# DBRG-J   index -1 is out of bounds for axis 0 with size 0
# DCP-B   index -1 is out of bounds for axis 0 with size 0
# DCP-C   index -1 is out of bounds for axis 0 with size 0
# DEED   index -1 is out of bounds for axis 0 with size 0
# DHCNL   index -1 is out of bounds for axis 0 with size 0
# DHR-B   index -1 is out of bounds for axis 0 with size 0
# DJCB   index -1 is out of bounds for axis 0 with size 0
# DLNG-A   index -1 is out of bounds for axis 0 with size 0
# DLNG-B   index -1 is out of bounds for axis 0 with size 0
# DLR-J   index -1 is out of bounds for axis 0 with size 0
# DLR-K   index -1 is out of bounds for axis 0 with size 0
# DLR-L   index -1 is out of bounds for axis 0 with size 0
# DMAQR   index -1 is out of bounds for axis 0 with size 0
# DOUG   index -1 is out of bounds for axis 0 with size 0
# DRH-A   index -1 is out of bounds for axis 0 with size 0
# DSX-B   index -1 is out of bounds for axis 0 with size 0
# DTLA-   index -1 is out of bounds for axis 0 with size 0
# DUK-A   index -1 is out of bounds for axis 0 with size 0
# DX-C   index -1 is out of bounds for axis 0 with size 0
# ECC-D   index -1 is out of bounds for axis 0 with size 0
# ECF-A   index -1 is out of bounds for axis 0 with size 0
# EDTXW   index -1 is out of bounds for axis 0 with size 0
# EFC-A   index -1 is out of bounds for axis 0 with size 0
# EFC-B   index -1 is out of bounds for axis 0 with size 0
# ENTXW   index -1 is out of bounds for axis 0 with size 0
# EP-C   index -1 is out of bounds for axis 0 with size 0
# EPR-C   index -1 is out of bounds for axis 0 with size 0
# EPR-E   index -1 is out of bounds for axis 0 with size 0
# EPR-G   index -1 is out of bounds for axis 0 with size 0
# EQC-D   index -1 is out of bounds for axis 0 with size 0
# EQH-A   index -1 is out of bounds for axis 0 with size 0
# EQH-C   index -1 is out of bounds for axis 0 with size 0
# ESAC   index -1 is out of bounds for axis 0 with size 0
# ET-C   index -1 is out of bounds for axis 0 with size 0
# ET-D   index -1 is out of bounds for axis 0 with size 0
# ET-E   index -1 is out of bounds for axis 0 with size 0
# ETI-   index -1 is out of bounds for axis 0 with size 0
# EVE   index -1 is out of bounds for axis 0 with size 0
# F-B   index -1 is out of bounds for axis 0 with size 0
# F-C   index -1 is out of bounds for axis 0 with size 0
# FBRT-E   index -1 is out of bounds for axis 0 with size 0
# FHN-B   index -1 is out of bounds for axis 0 with size 0
# FHN-C   index -1 is out of bounds for axis 0 with size 0
# FHN-D   index -1 is out of bounds for axis 0 with size 0
# FHN-E   index -1 is out of bounds for axis 0 with size 0
# FHN-F   index -1 is out of bounds for axis 0 with size 0
# FIAC   index -1 is out of bounds for axis 0 with size 0
# FINV   index -1 is out of bounds for axis 0 with size 0
# FNB-E   index -1 is out of bounds for axis 0 with size 0
# FRC-H   index -1 is out of bounds for axis 0 with size 0
# FRC-I   index -1 is out of bounds for axis 0 with size 0
# FRC-J   index -1 is out of bounds for axis 0 with size 0
# FRC-K   index -1 is out of bounds for axis 0 with size 0
# FRC-L   index -1 is out of bounds for axis 0 with size 0
# FRC-M   index -1 is out of bounds for axis 0 with size 0
# FRC-N   index -1 is out of bounds for axis 0 with size 0
# FRT-C   index -1 is out of bounds for axis 0 with size 0
# GAB-G   index -1 is out of bounds for axis 0 with size 0
# GAB-H   index -1 is out of bounds for axis 0 with size 0
# GAB-K   index -1 is out of bounds for axis 0 with size 0
# GAM-B   index -1 is out of bounds for axis 0 with size 0
# GBRGR   index -1 is out of bounds for axis 0 with size 0
# GDL-C   index -1 is out of bounds for axis 0 with size 0
# GDV-H   index -1 is out of bounds for axis 0 with size 0
# GDV-K   index -1 is out of bounds for axis 0 with size 0
# GECCM   index -1 is out of bounds for axis 0 with size 0
# GGN-B   index -1 is out of bounds for axis 0 with size 0
# GGT-E   index -1 is out of bounds for axis 0 with size 0
# GGT-G   index -1 is out of bounds for axis 0 with size 0
# GL-D   index -1 is out of bounds for axis 0 with size 0
# GLOG-A   index -1 is out of bounds for axis 0 with size 0
# GLOP-A   index -1 is out of bounds for axis 0 with size 0
# GLOP-B   index -1 is out of bounds for axis 0 with size 0
# GLOP-C   index -1 is out of bounds for axis 0 with size 0
# GLP-A   index -1 is out of bounds for axis 0 with size 0
# GLP-B   index -1 is out of bounds for axis 0 with size 0
# GLU-A   index -1 is out of bounds for axis 0 with size 0
# GLU-B   index -1 is out of bounds for axis 0 with size 0
# GMBLW   index -1 is out of bounds for axis 0 with size 0
# GMRE-A   index -1 is out of bounds for axis 0 with size 0
# GNE-A   index -1 is out of bounds for axis 0 with size 0
# GNL-A   index -1 is out of bounds for axis 0 with size 0
# GNL-B   index -1 is out of bounds for axis 0 with size 0
# GNT-A   index -1 is out of bounds for axis 0 with size 0
# GPMT-A   index -1 is out of bounds for axis 0 with size 0
# GS-A   index -1 is out of bounds for axis 0 with size 0
# GS-C   index -1 is out of bounds for axis 0 with size 0
# GS-D   index -1 is out of bounds for axis 0 with size 0
# GS-J   index -1 is out of bounds for axis 0 with size 0
# GS-K   index -1 is out of bounds for axis 0 with size 0
# GSL-B   index -1 is out of bounds for axis 0 with size 0
# GSMGW   index -1 is out of bounds for axis 0 with size 0
# GTAC   index -1 is out of bounds for axis 0 with size 0
# GUT-C   index -1 is out of bounds for axis 0 with size 0
# HFRO-A   index -1 is out of bounds for axis 0 with size 0
# HHGCR   index -1 is out of bounds for axis 0 with size 0
# HIG-G   index -1 is out of bounds for axis 0 with size 0
# HL-B   index -1 is out of bounds for axis 0 with size 0
# HPP-C   index -1 is out of bounds for axis 0 with size 0
# HT-C   index -1 is out of bounds for axis 0 with size 0
# HT-D   index -1 is out of bounds for axis 0 with size 0
# HT-E   index -1 is out of bounds for axis 0 with size 0
# HWM-   index -1 is out of bounds for axis 0 with size 0
# IBO   index -1 is out of bounds for axis 0 with size 0
# IBTD   index -1 is out of bounds for axis 0 with size 0
# ICR-A   index -1 is out of bounds for axis 0 with size 0
# IFIN   index -1 is out of bounds for axis 0 with size 0
# IGICW   index -1 is out of bounds for axis 0 with size 0
# IGZ   index -1 is out of bounds for axis 0 with size 0
# IIPR-A   index -1 is out of bounds for axis 0 with size 0
# IMACW   index -1 is out of bounds for axis 0 with size 0
# IMAQR   index -1 is out of bounds for axis 0 with size 0
# INN-E   index -1 is out of bounds for axis 0 with size 0
# INN-F   index -1 is out of bounds for axis 0 with size 0
# IRRX   index -1 is out of bounds for axis 0 with size 0
# IVR-B   index -1 is out of bounds for axis 0 with size 0
# IVR-C   index -1 is out of bounds for axis 0 with size 0
# JPM-C   index -1 is out of bounds for axis 0 with size 0
# JPM-D   index -1 is out of bounds for axis 0 with size 0
# JPM-J   index -1 is out of bounds for axis 0 with size 0
# JPM-K   index -1 is out of bounds for axis 0 with size 0
# JPM-L   index -1 is out of bounds for axis 0 with size 0
# JPM-M   index -1 is out of bounds for axis 0 with size 0
# JUN   index -1 is out of bounds for axis 0 with size 0
# KDRN   index -1 is out of bounds for axis 0 with size 0
# KERNW   index -1 is out of bounds for axis 0 with size 0
# KEY-I   index -1 is out of bounds for axis 0 with size 0
# KEY-J   index -1 is out of bounds for axis 0 with size 0
# KEY-K   index -1 is out of bounds for axis 0 with size 0
# KIM-L   index -1 is out of bounds for axis 0 with size 0
# KIM-M   index -1 is out of bounds for axis 0 with size 0
# KKR-C   index -1 is out of bounds for axis 0 with size 0
# KREF-A   index -1 is out of bounds for axis 0 with size 0
# LCAHW   index -1 is out of bounds for axis 0 with size 0
# LFACW   index -1 is out of bounds for axis 0 with size 0
# LFT-A   index -1 is out of bounds for axis 0 with size 0
# LGF   index -1 is out of bounds for axis 0 with size 0
# LVAC   index -1 is out of bounds for axis 0 with size 0
# LXP-C   index -1 is out of bounds for axis 0 with size 0
# MAA-I   index -1 is out of bounds for axis 0 with size 0
# MCAER   index -1 is out of bounds for axis 0 with size 0
# MCAFR   index -1 is out of bounds for axis 0 with size 0
# MCAGR   index -1 is out of bounds for axis 0 with size 0
# MDGSW   index -1 is out of bounds for axis 0 with size 0
# MER-K   index -1 is out of bounds for axis 0 with size 0
# MET-A   index -1 is out of bounds for axis 0 with size 0
# MET-E   index -1 is out of bounds for axis 0 with size 0
# MET-F   index -1 is out of bounds for axis 0 with size 0
# MFA-B   index -1 is out of bounds for axis 0 with size 0
# MFA-C   index -1 is out of bounds for axis 0 with size 0
# MITT-A   index -1 is out of bounds for axis 0 with size 0
# MITT-B   index -1 is out of bounds for axis 0 with size 0
# MITT-C   index -1 is out of bounds for axis 0 with size 0
# MMCA   index -1 is out of bounds for axis 0 with size 0
# MNTN   index -1 is out of bounds for axis 0 with size 0
# MS-A   index -1 is out of bounds for axis 0 with size 0
# MS-E   index -1 is out of bounds for axis 0 with size 0
# MS-F   index -1 is out of bounds for axis 0 with size 0
# MS-I   index -1 is out of bounds for axis 0 with size 0
# MS-K   index -1 is out of bounds for axis 0 with size 0
# MS-L   index -1 is out of bounds for axis 0 with size 0
# MS-O   index -1 is out of bounds for axis 0 with size 0
# MTVC   index -1 is out of bounds for axis 0 with size 0
#
# ======done==============
